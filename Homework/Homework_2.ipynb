# %%
def histogram(string_list):
    
    new_dict = dict()

    for letter in string_list:
        letter_type = string_list[letter]
        print(new_dict[letter_type])

# %%
def histogram(string_list):

    hist = dict()

    for word in string_list:
        if word in hist:
            hist[word] += 1
        else:
            hist[word] = 1

    return hist


print(histogram(['word', 'text', 'word', 'word', 'string']))
# Out:
# {'word': 3, 'text': 1, 'string': 1}

# %%
def reverse_tuple(tuple_set1, tuple_set2):

    for pair in tuple_set1:
        reverse = (pair[1], pair[0])

        if reverse in tuple_set2:
            return True

    return False


print(reverse_tuple({(1, 2), (3, 4)}, {(2, 1), (5, 6)}))
print(reverse_tuple({(1, 2), (3, 4)}, {(1, 2), (2, 3)}))
# Out:
# True
# False

# %%
histogram(string_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 histogram(string_list)
#
# Cell In[5], line 7, in histogram(string_list)
#       5 for letter in range(len(string_list)):
#       6     letter_type = string_list[letter]
# ----> 7     print(new_dict[letter_type])
#
# KeyError: 'a'

# %%
string_list = ["a","b","c","d"]

# %%
def reverse_tuple(tuple_set1, tuple_set2):

    tuple_set2_rev = tuple_set2[::-1]

    if tuple_set1 == tuple_set2_rev:

       return True

    return True

# %%
reverse_tuple((1, 2), (3, 4))
# Out:
# True

# %%
tuple_set2_rev = tuple_set2[::-1]
print(tuple_set2_rev)
# Out:
# ((5, 6), (2, 1))

# %%
tuple_set1 = {(1, 2), (3, 4)}
tuple_set2 = ((2, 1), (5, 6))
