# %% [markdown]
# ## String slicing

# %%
# You can "slice" strings, lists, etc. by referencing a range of indices
word = 'testing'
print(word[0])      # index 0
print(word[0:2])    # index 0 (inclusive) to 2 (exclusive)
print(word[3:])     # index 3 (inclusive) to the end of the string
print(word[::2])    # index 0 (inclusive) to the end, only even numbered indices

# %% [markdown]
# ## Practice
#
# 1. Write a function that takes a string as input and returns a tuple. The first element of the tuple is the first half (rounded down) of the string and the second element is the second half of the string. For example, the input 'testing' should return ('tes', 'ting')
#
# 2. Write a function that takes a string as input and returns a tuple. The first element of the tuple is the substring formed by all the even indices and the second element is the substring formed by all the odd indices. For example, the input 'testing' should return ('tsig', 'etn').

# %%
int(len(input_str)/2)
# Out:
# 3

# %%
def string_halves(input_str):
   half = int(len(input_str)/2)
   print(input_str[0:half])
   print(input_str[half:])

# %%
string_halves(input_str)
# Out:
# tes
# ting

# %%
def string_halves_2(input_str):

    half_len = int(len(input_str) / 2)
    left_half_str = input_str[0:half_len]
    right_half_str = input_str[half_len:len(input_str)]

    return (left_half_str,right_half_str)

string_halves_2(input_str)
# Out:
# ('tes', 'ting')

# %%
def string_split(input_str):
    print(input_str[::2])
    print(input_str[1::2])

# %%
string_split(input_str)
# Out:
# tsig
# etn

# %%
def string_split(input_str):

# %% [markdown]
# ## Files

# %%
def file_demo(search_char):
    """
    Demonstrates opening, reading from, and writing to files

    :param search_char: character to search for in each word
    :return: None (writes all words ending in search_char to file)
    """

    # using "with" is the cleanest way to open a file
    # the file will automatically be closed when you exit this context
    with open('words.txt', 'r') as read_file: # 'r' keyword indicates read-only

        with open('output.txt', 'w') as write_file: # 'w' keyword indicates writing

            for line in read_file: # loops over each line in the file

                # Strip off all whitespace (in this case, the newline character)
                line = line.strip()

                # If line ends with search_char, then print to file
                # Manually reattach the newline character so we get one string per line
                if line[-1] == search_char:
                    write_file.write(line + '\n')

# %%
file_demo('x')

# %%
s = 'pins'
s[::-1]

# %% [markdown]
# ## Practice
#
# 1. Write a function that takes a string as input and returns a tuple. The first element of the tuple is the first half (rounded down) of the string and the second element is the second half of the string. For example, the input 'testing' should return ('tes', 'ting')
#
# 2. Write a function that takes a string as input and returns a tuple. The first element of the tuple is the substring formed by all the even indices and the second element is the substring formed by all the odd indices. For example, the input 'testing' should return ('tsig', 'etn').
